# %% [markdown]
# <a href="https://colab.research.google.com/github/RASIUT/ML/blob/main/MatplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
# If we use %matplotlib inline then we'll get some [] kind of thing before each graph
# to overcome it either use plt.plot(x, y); (Use semicolon) or use plt.plot(x,y) plt.show()
plt.plot(x, y)
plt.show()

# %%
# 1st method (Longer version of plt.plot();)

fig = plt.figure() # creates a figure
ax = fig.add_subplot()
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# 3rd method (recommeneded)
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize = (10, 10))

# 3. Plot data
ax.plot(x, y)

# 4. Customise Plot
ax.set(title = "Simple Plot", xlabel = "x-axis", ylabel = "y-axis")

# 5. Save & show (you save the whole figure)
fig.savefig("/content/sample_data")

# %% [markdown]
# # Making figures with Numpy array
#
# We want:
# * Line Plot
# * Scatter plot
# * Bar Plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %% [markdown]
# ## Line Plot

# %%
# Create some data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2)

# Show the plot
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# Use same data to make a Scatter plot (dots)
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond butter": 10, "Peanut butter": 8, "Cashew butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title = "Butter Store", xlabel = "", ylabel = "Pricess")
plt.show()

# %% [markdown]
# ### Horizontal Bar Plot

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
ax.set(title = "Butter store", xlabel = "Prices", ylabel = "")
plt.show()

# %% [markdown]
# ## Histograms

# %%
# Make some data for histograms and plot it
np.random.seed(0)
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# # Two options for subplots

# %% [markdown]
# ## Using Subplot with tuple format

# %%
# Subplot option 1 (using tuple format)
np.random.seed(0)
# pass axis in tuple format
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 5))

# Plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));  # Generate an array of thousand integers

# %% [markdown]
# ## Using subplot with indices

# %%
# Subplot option 2 (using indices)
np.random.seed(0)

fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 5))

# Plot to each different index
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));  # Generate an array of thousand integers

# %% [markdown]
# # Plotting from Pandas DataFrames

# %%
import pandas as pd

# %%
# Make a DataFrame
car_sales = pd.read_csv("/content/050 car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
np.random.seed(0)
ts = pd.Series(np.random.randn(1000), index = pd.date_range("17/1/2025", periods = 1000))
ts = ts.cumsum() # returns cumulative sum
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Remove '$' sign and '.' from the price
car_sales["Price"] = car_sales["Price"].str.replace("[\$\, \.]", "", regex = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last two extra zeroes which were after '.'
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("17/01/2025", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2025-01-17
# 1   Honda    Red          87899      4   5000 2025-01-18
# 2  Toyota   Blue          32549      3   7000 2025-01-19
# 3     BMW  Black          11179      5  22000 2025-01-20
# 4  Nissan  White         213095      4   3500 2025-01-21
# 5  Toyota  Green          99213      4   4500 2025-01-22
# 6   Honda   Blue          45698      4   7500 2025-01-23
# 7   Honda   Blue          54738      4   7000 2025-01-24
# 8  Toyota  White          60000      4   6250 2025-01-25
# 9  Nissan  White          31600      4   9700 2025-01-26

# %%
# Add total price column which will add all the prices (Cumulatively)
# Use cumsum()

car_sales["TotalSales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  TotalSales
# 0  Toyota  White         150043      4   4000 2025-01-17        4000
# 1   Honda    Red          87899      4   5000 2025-01-18        9000
# 2  Toyota   Blue          32549      3   7000 2025-01-19       16000
# 3     BMW  Black          11179      5  22000 2025-01-20       38000
# 4  Nissan  White         213095      4   3500 2025-01-21       41500
# 5  Toyota  Green          99213      4   4500 2025-01-22       46000
# 6   Honda   Blue          45698      4   7500 2025-01-23       53500
# 7   Honda   Blue          54738      4   7000 2025-01-24       60500
# 8  Toyota  White          60000      4   6250 2025-01-25       66750
# 9  Nissan  White          31600      4   9700 2025-01-26       76450

# %%
# Let's plot the total sales
car_sales.plot(x = "Sale Date", y = "TotalSales")
plt.show()

# %%
# Convert Price column integer datatype
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot the scatter plot
car_sales.plot(x="Odometer (KM)", y = "Price", kind = "scatter")
plt.show()

# %% [markdown]
# ## Bar Graph

# %%
np.random.seed(0)
# Create the data
x = np.random.rand(10, 4)
x

# Turn it into a DataFrame
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.548814  0.715189  0.602763  0.544883
# 1  0.423655  0.645894  0.437587  0.891773
# 2  0.963663  0.383442  0.791725  0.528895
# 3  0.568045  0.925597  0.071036  0.087129
# 4  0.020218  0.832620  0.778157  0.870012
# 5  0.978618  0.799159  0.461479  0.780529
# 6  0.118274  0.639921  0.143353  0.944669
# 7  0.521848  0.414662  0.264556  0.774234
# 8  0.456150  0.568434  0.018790  0.617635
# 9  0.612096  0.616934  0.943748  0.681820

# %%
df.plot(kind = "bar")
plt.show()

# %%
df.plot.bar()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  TotalSales
# 0  Toyota  White         150043      4   4000 2025-01-17        4000
# 1   Honda    Red          87899      4   5000 2025-01-18        9000
# 2  Toyota   Blue          32549      3   7000 2025-01-19       16000
# 3     BMW  Black          11179      5  22000 2025-01-20       38000
# 4  Nissan  White         213095      4   3500 2025-01-21       41500
# 5  Toyota  Green          99213      4   4500 2025-01-22       46000
# 6   Honda   Blue          45698      4   7500 2025-01-23       53500
# 7   Honda   Blue          54738      4   7000 2025-01-24       60500
# 8  Toyota  White          60000      4   6250 2025-01-25       66750
# 9  Nissan  White          31600      4   9700 2025-01-26       76450

# %%
car_sales.plot(x = "Make", y = "Odometer (KM)", kind = "bar")
plt.show()

# %% [markdown]
# ## Histograms

# %%
car_sales["Odometer (KM)"].plot(kind = "hist")
plt.show()

# %%
car_sales["Odometer (KM)"].plot.hist()
plt.show()

# %%
# bins are number of x axes elements
car_sales["Odometer (KM)"].plot.hist(bins = 10)
plt.show()

# %%
heart_disease = pd.read_csv("/content/087 heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create histogram of age
heart_disease["age"].plot.hist(bins = 10)
plt.show()

# %%
heart_disease.plot.hist(figsize = (10, 30), subplots = True)
plt.show()

# %% [markdown]
# ## Pyplot vs Matplotlib oo (Object Oriented) method
# * When plotting something quickly, use pyplot
# * When plotting something more advanced, use the Object Oriented or OO method

# %%
# Object Oriented Method

# Make a new DataFrame from given dataframe of all the people whose age > 50
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method
over_50.plot(kind = "scatter", x = 'age', y = "chol", c = "target")
plt.show()

# %%
# OO method mixed with pyplot method
fig, ax = plt.subplots(figsize = (10, 6))
over_50.plot(kind = "scatter", x = "age", y = "chol", c = "target", ax = ax)
ax.set_xlim([45, 80])   # Changes x limit from 45 to 80
plt.show()

# %% [markdown]
# ## Object Oriented from scratch

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize = (10, 6))

# 1. Plot the data
scatter = ax.scatter(x = over_50["age"], y = over_50["chol"], c = over_50["target"])

# 2. Customize
ax.set(title = "Heart Disease and Cholestrol levels", xlabel = "Age", ylabel = "Cholestrol")

# 3. Add legends
ax.legend(*scatter.legend_elements(), title = "Target")

# 4. Add a horizontal line (i.e. mean of cholestrol)
ax.axhline(over_50["chol"].mean(), linestyle = "--", color = "red")

# 5. Add a vertical line (i.e. mean of age)
ax.axvline(over_50["age"].mode()[0], linestyle = "--", color = "blue")

# 6. Show the plot
plt.show()

# %%
# Subplot of chol, age, thalach
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 10))

# 1. Add data to ax[0]
scatter = ax[0].scatter(x = over_50["age"], y = over_50["chol"], c = over_50["target"])

# 2. Add a title, xlabel and ylabel
ax[0].set(title = "Heart Disease and Cholestrol levels", xlabel = "Age", ylabel = "Cholestrol")

# 3. Add legend
ax[0].legend(*scatter.legend_elements(), title = "Target")

# 4. Add a chol mean line
ax[0].axhline(over_50["chol"].mean(), linestyle = "--", color = "red")

# -------------------------- Now for ax[1]
# 1. Add data to ax[1]
scatter = ax[1].scatter(x = over_50["age"], y = over_50["thalach"], c = over_50["target"])

# 2. Add a title, xlabel and ylabel
ax[1].set(title = "Heart Disease and Max heart rate", xlabel = "Age", ylabel = "Max Heart Rate")

# 3. Add legend
ax[1].legend(*scatter.legend_elements(), title = "Target")

# 4. Add a chol mean line
ax[1].axhline(over_50["thalach"].mean(), linestyle = "--", color = "red")

#--------------------------
# 5. Add title to figure
fig.suptitle("Heart Disease Analysis", fontsize = 16, fontweight="bold")

# 6. show the plot
plt.show()

# %% [markdown]
# ## Customization of plots

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use("seaborn-v0_8")

car_sales["Price"].plot()
plt.show()

# %%
car_sales.plot(x = "Odometer (KM)", y = "Price", kind = "scatter")
plt.show()

# %%
plt.style.use("ggplot")

car_sales["Price"].plot()
plt.show()

# %%
# Customize titles and legends

# Create some dummy data
x = np.random.randn(10, 4) # Generates a 10x4 random matrix

# Create DataFrame
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])

# Create a simple plot
# Customize the plot with set() method
ax = df.plot(kind = "bar")

# Add some lables and a title
ax.set(title = "Random Number Bar Graph from DataFrame", xlabel = "Row number", ylabel = "Random number")

# Make the legend visible
ax.legend().set_visible(True)

# show the plot
plt.show()

# %%
plt.style.use("seaborn-v0_8-whitegrid")
## OO method from scratch
fig, ax = plt.subplots(figsize = (10, 6))

# 1. Plot the data
# cmap will change the color of the points
scatter = ax.scatter(x = over_50["age"], y = over_50["chol"], c = over_50["target"], cmap="summer")

# 2. Customize
ax.set(title = "Heart Disease and Cholestrol levels", xlabel = "Age", ylabel = "Cholestrol")

# 3. Add legends
ax.legend(*scatter.legend_elements(), title = "Target")

# 4. Add a horizontal line (i.e. mean of cholestrol)
ax.axhline(over_50["chol"].mean(), linestyle = "--", color = "red")

# 5. Add a vertical line (i.e. mean of age)
ax.axvline(over_50["age"].mode()[0], linestyle = "--", color = "blue")

# 6. Show the plot
plt.show()

# %% [markdown]
# ## Customizing x and y axis limitations

# %%
# Subplot of chol, age, thalach
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 10))

# 1. Add data to ax[0]
scatter = ax[0].scatter(x = over_50["age"], y = over_50["chol"], c = over_50["target"], cmap = "winter")

# 2. Add a title, xlabel and ylabel
ax[0].set(title = "Heart Disease and Cholestrol levels", xlabel = "Age", ylabel = "Cholestrol")

# 3. Change the x - axis limits using set_xlim()
ax[0].set_xlim([50, 80])

# 4. Add legend
ax[0].legend(*scatter.legend_elements(), title = "Target")

# 5. Add a chol mean line
ax[0].axhline(over_50["chol"].mean(), linestyle = "--", color = "red")

# -------------------------- Now for ax[1]
# 1. Add data to ax[1]
scatter = ax[1].scatter(x = over_50["age"], y = over_50["thalach"], c = over_50["target"], cmap = "summer")

# 2. Add a title, xlabel and ylabel
ax[1].set(title = "Heart Disease and Max heart rate", xlabel = "Age", ylabel = "Max Heart Rate")

# 3. Change the x - axis and y-axis limits using set_xlim() & set_ylim()
ax[1].set_xlim([50, 80])
ax[1].set_ylim([60, 200])

# 4. Add legend
ax[1].legend(*scatter.legend_elements(), title = "Target")

# 5. Add a chol mean line
ax[1].axhline(over_50["thalach"].mean(), linestyle = "--", color = "red")

#--------------------------
# 6. Add title to figure
fig.suptitle("Heart Disease Analysis", fontsize = 16, fontweight="bold")

# 7. show the plot
plt.show()

# %% [markdown]
# # Saving and Sharing of the graphs

# %%
fig.savefig("heart_disease.jpg")
