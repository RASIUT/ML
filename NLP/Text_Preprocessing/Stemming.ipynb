# %% [markdown]
# <a href="https://colab.research.google.com/github/RASIUT/ML/blob/main/NLP/Text_Preprocessing/Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
words = ["eating", "eats", "eaten", "writing", "writes", "programming", "programs", "history", "finally", "finalize"]

# %% [markdown]
# ###PorterStemmer

# %%
from nltk.stem import PorterStemmer
porter_stemmer = PorterStemmer()
for word in words:
  print(word + "----->" + porter_stemmer.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final
# finalize----->final

# %% [markdown]
# ### RegexpStemmer Class

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing|s$|e$|able$', min=4)       #  RegexpStemmer('ing') -> remove any ing in the word
                                                            #  RegexpStemmer('ing$') -> remove ing from the last of the word
print(reg_stemmer.stem('ingeating'))

for word in words:
  print(word + "------>" + reg_stemmer.stem(word))
# Out:
# eat
# eating------>eat
# eats------>eat
# eaten------>eaten
# writing------>writ
# writes------>write
# programming------>programm
# programs------>program
# history------>history
# finally------>finally
# finalize------>finaliz

# %% [markdown]
# ### Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer('english')

for word in words:
  print(word + "----->" + snowball_stemmer.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final
# finalize----->final
