# %% [markdown]
# <a href="https://colab.research.google.com/github/RASIUT/ML/blob/main/NLP/Text_Preprocessing/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Install NLTK

# %%
# !pip install nltk

# %% [markdown]
# ##Define corpus (paragraph)

# %%
corpus = """Hello welcome to RASIUT's notes.
If you want more content! You can go through my GitHub for more content. """

# %%
print(corpus)
print('------------')
corpus
# Out:
# Hello welcome to RASIUT's notes.
# If you want more content! You can go through my GitHub for more content.
# ------------
# "Hello welcome to RASIUT's notes.\nIf you want more content! You can go through my GitHub for more content. "

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### Sentence --> Paragraphs

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
  print(sentence)
# Out:
# Hello welcome to RASIUT's notes.
# If you want more content!
# You can go through my GitHub for more content.

# %% [markdown]
# ### Paragraph --> words OR sentence --> words

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'RASIUT',
#  "'s",
#  'notes',
#  '.',
#  'If',
#  'you',
#  'want',
#  'more',
#  'content',
#  '!',
#  'You',
#  'can',
#  'go',
#  'through',
#  'my',
#  'GitHub',
#  'for',
#  'more',
#  'content',
#  '.']

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', 'to', 'RASIUT', "'s", 'notes', '.']
# ['If', 'you', 'want', 'more', 'content', '!']
# ['You', 'can', 'go', 'through', 'my', 'GitHub', 'for', 'more', 'content', '.']

# %% [markdown]
# ####**Handling punctuation:**
#
# **wordpunct_tokenize()**

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'RASIUT',
#  "'",
#  's',
#  'notes',
#  '.',
#  'If',
#  'you',
#  'want',
#  'more',
#  'content',
#  '!',
#  'You',
#  'can',
#  'go',
#  'through',
#  'my',
#  'GitHub',
#  'for',
#  'more',
#  'content',
#  '.']

# %% [markdown]
# ####**Treat fullstop (.) with the same word**

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'RASIUT',
#  "'s",
#  'notes.',
#  'If',
#  'you',
#  'want',
#  'more',
#  'content',
#  '!',
#  'You',
#  'can',
#  'go',
#  'through',
#  'my',
#  'GitHub',
#  'for',
#  'more',
#  'content',
#  '.']
