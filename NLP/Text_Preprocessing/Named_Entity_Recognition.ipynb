# %% [markdown]
# <a href="https://colab.research.google.com/github/RASIUT/ML/blob/main/NLP/Text_Preprocessing/Named_Entity_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."

"""
Person Eg: Rahul Mansingh Rout
Place Or Location Eg: India
Date Eg: January, 29-01-2004
Time  Eg: 5:16pm
Money Eg: 1 million dollar
Organization Eg: xNeuron Private Limited
Percent Eg: 20%, twenty percent
"""
# Out:
# '\nPerson Eg: Rahul Mansingh Rout\nPlace Or Location Eg: India\nDate Eg: January, 29-01-2004\nTime  Eg: 5:16pm\nMoney Eg: 1 million dollar\nOrganization Eg: xNeuron Private Limited\nPercent Eg: 20%, twenty percent\n'

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

words = word_tokenize(sentence)

# OR can also use         =>    words = sentence.split(' ')

tag_elements = nltk.pos_tag(words)

nltk.ne_chunk(tag_elements).draw
# Out:
# <bound method Tree.draw of Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('GPE', [('French', 'JJ')]), ('engineer', 'NN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')])>

# %% [markdown]
# RESULT WE CAN EXPECT FROM THE TREE IF WE RUN IN JUPITER NOTEBOOK OR LOCAL HOST

# %% [markdown]
# ![image.png](data:image/png;base64,...)
