# %% [markdown]
# <a href="https://colab.research.google.com/github/RASIUT/ML/blob/main/Automated_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Automated EDA**

# %% [markdown]
# ## **Pandas Profiling (ydata-profiling.ProfileReport)**

# %%
# We'll be using Pandas profiling
# !pip install ydata-profiling

# %%
# Import ProfileReport
from ydata_profiling import ProfileReport
import pandas as pd
import seaborn as sns

# %%
# Load dataset
df = sns.load_dataset('tips')
df.head(2)

# %%
# Create a profile
profile = ProfileReport(df, explorative=True)

# %%
# Save it to a variable
profile.to_file('output.html')

# %%
profile

# %% [markdown]
# ## **DTale**

# %% [markdown]
# **Use in Jupyter**

# %%
# !pip install dtale

# %%
# Import pandas and pd
import pandas as pd
import seaborn as sns

# %%
# Load datasets
df = sns.load_dataset('titanic')

# %%
# Import dtale
import dtale
dtale.show(df)

# %% [markdown]
# ## **Sweet viz**

# %%
# !pip install sweetviz

# %%
import sweetviz as sv
report = sv.analyze(df)
report.show_html('new_report.html')

# %% [markdown]
# ## **DataPrep**

# %%
# !pip install dataprep

# %%
from dataprep.eda import create_report
create_report(df)

# %% [markdown]
# ## **LUX**

# %% [markdown]
# **Try in LUX's Jupyter**

# %%
# !pip install lux

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/college.csv")
df

# %%
# !pip install lux-api
# !jupyter nbextension install --py luxwidget
# !jupyter nbextension enable --py luxwidget

# %%
import lux
lux.config.default_display = "lux"

# %%
df

# %% [markdown]
# ## Pandas Visual Analysis

# %%
# !pip install pandas_visual_analysis

# %% [markdown]
# ### Need to insert these third-party custom widget manager
# **Just Run the code it'll automaticall install**

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %% [markdown]
# ### Pandas Visual Analysis

# %%
from pandas_visual_analysis import VisualAnalysis
df = sns.load_dataset('tips')
VisualAnalysis(df)
